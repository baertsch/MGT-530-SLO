# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Wednesday

# %%
repo_url = 'https://raw.githubusercontent.com/baertsch/MGT-530-SLO/main/'
wed_df = pd.read_csv(repo_url+'demand_wed.csv')
dm_wed = pd.read_csv(repo_url+'data/dm_mercredi.csv',header=None)

# %%
to_exclude = wed_df[wed_df['adjusted_demand_wed']==0]['index'].values.tolist()
to_exclude
# Out:
# [70,
#  82,
#  100,
#  101,
#  102,
#  107,
#  108,
#  112,
#  113,
#  117,
#  125,
#  127,
#  131,
#  134,
#  136,
#  137,
#  138,
#  140,
#  141,
#  143,
#  144,
#  145,
#  147,
#  150,
#  153,
#  155,
#  156,
#  157,
#  158,
#  159,
#  162,
#  164,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  174,
#  175,
#  176,
#  177,
#  179,
#  180,
#  181,
#  182,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  194,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  212,
#  213,
#  214,
#  215,
#  216,
#  218,
#  219,
#  220,
#  221,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  230,
#  231,
#  232,
#  233,
#  234,
#  236,
#  237]

# %%
dm_wed
# Out:
#        0        1        2        3        4        5        6        7    \
# 0      NaN   0.0000   0.0000   0.0000   1.0000   1.0000   1.0000   2.0000
# 1      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 2      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 3      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 4      1.0   2.6786   2.6786   2.6786      inf      inf      inf   3.9804
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 326  232.0  69.3386  69.3386  69.3386  71.4946  71.4946  71.4946  69.4933
# 327  233.0  69.9441  69.9441  69.9441  68.0584  68.0584  68.0584  69.8029
# 328  234.0  72.1044  72.1044  72.1044  74.2604  74.2604  74.2604  72.2591
# 329  236.0  74.0778  74.0778  74.0778  76.2338  76.2338  76.2338  74.2325
# 330  237.0  77.0503  77.0503  77.0503  79.2062  79.2062  79.2062  77.2050
#
#          8        9    ...       321       322       323       324       325  \
# ...

# %%
dm_wed = dm_wed[~dm_wed[0].isin(to_exclude)]

# %%
dm_wed
# Out:
#        0        1        2        3        4        5        6        7    \
# 0      NaN   0.0000   0.0000   0.0000   1.0000   1.0000   1.0000   2.0000
# 1      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 2      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 3      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 4      1.0   2.6786   2.6786   2.6786      inf      inf      inf   3.9804
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 262  160.0  37.8368  37.8368  37.8368  39.9928  39.9928  39.9928  37.9915
# 263  161.0  38.1101  38.1101  38.1101  40.2660  40.2660  40.2660  38.2647
# 265  163.0  38.4266  38.4266  38.4266  40.5826  40.5826  40.5826  38.5813
# 267  165.0  38.9650  38.9650  38.9650  37.1648  37.1648  37.1648  41.6522
# 275  173.0  40.1119  40.1119  40.1119  42.2679  42.2679  42.2679  40.2666
#
#          8        9    ...       321       322       323       324       325  \
# ...

# %%
test =  dm_wed.loc[:, ~dm_wed.loc[0].isin(to_exclude)]
test
# Out:
#        0        1        2        3        4        5        6        7    \
# 0      NaN   0.0000   0.0000   0.0000   1.0000   1.0000   1.0000   2.0000
# 1      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 2      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 3      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 4      1.0   2.6786   2.6786   2.6786      inf      inf      inf   3.9804
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 262  160.0  37.8368  37.8368  37.8368  39.9928  39.9928  39.9928  37.9915
# 263  161.0  38.1101  38.1101  38.1101  40.2660  40.2660  40.2660  38.2647
# 265  163.0  38.4266  38.4266  38.4266  40.5826  40.5826  40.5826  38.5813
# 267  165.0  38.9650  38.9650  38.9650  37.1648  37.1648  37.1648  41.6522
# 275  173.0  40.1119  40.1119  40.1119  42.2679  42.2679  42.2679  40.2666
#
#          8        9    ...       246       250       252       253       256  \
# ...

# %%
dm_wed = test.copy()
dm_wed = dm_wed.reset_index(drop=True)
dm_wed
# Out:
#        0        1        2        3        4        5        6        7    \
# 0      NaN   0.0000   0.0000   0.0000   1.0000   1.0000   1.0000   2.0000
# 1      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 2      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 3      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 4      1.0   2.6786   2.6786   2.6786      inf      inf      inf   3.9804
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 232  160.0  37.8368  37.8368  37.8368  39.9928  39.9928  39.9928  37.9915
# 233  161.0  38.1101  38.1101  38.1101  40.2660  40.2660  40.2660  38.2647
# 234  163.0  38.4266  38.4266  38.4266  40.5826  40.5826  40.5826  38.5813
# 235  165.0  38.9650  38.9650  38.9650  37.1648  37.1648  37.1648  41.6522
# 236  173.0  40.1119  40.1119  40.1119  42.2679  42.2679  42.2679  40.2666
#
#          8        9    ...       246       250       252       253       256  \
# ...

# %%
wed_df1 = wed_df[~wed_df['index'].isin(to_exclude)]
wed_df1.reset_index(drop=True, inplace=True)
wed_df1
# Out:
#      index     Commune   NPA Commune d'annonce / District  full_demand_wed  \
# 0        0     Penthaz  1303                      Penthaz            100.0
# 1        0     Penthaz  1303                      Penthaz            100.0
# 2        0     Penthaz  1303                      Penthaz             46.0
# 3        1   Penthalaz  1305                    Penthalaz            100.0
# 4        1   Penthalaz  1305                    Penthalaz            100.0
# ..     ...         ...   ...                          ...              ...
# 231    160     Clarens  1815                     Montreux             56.0
# 232    161      Blonay  1807                     Montreux             59.0
# 233    163       Gimel  1188                        Gimel             26.0
# 234    165  Le Solliat  1347                    Le Chenit             32.0
# 235    173    Prangins  1197                     Prangins             38.0
#
#      distance_to_venoge_km       P_Y  adjusted_demand_wed
# ...

# %%
wed_df1.columns
# Out:
# Index(['index', 'Commune', 'NPA', 'Commune d'annonce / District',
#        'full_demand_wed', 'distance_to_venoge_km', 'P_Y',
#        'adjusted_demand_wed'],
#       dtype='object')

# %%
wed_df.iloc[:,:6].to_csv('demand_wed_full.csv', index=False)

# %%
wed_df1[['index','Commune','NPA',"Commune d'annonce / District",'adjusted_demand_wed','distance_to_venoge_km']].to_csv('adjusted_demand_wed.csv', index=False)

# %%
dm_wed.to_csv('adjusted_dm_wed.csv', index=False, header=False)

# %% [markdown]
# # Thursday

# %%
thu_df = pd.read_csv(repo_url+'demand_thu.csv')
dm_thu = pd.read_csv(repo_url+'data/dm_jeudi.csv',header=None)

# %%
to_exclude_thu = thu_df[thu_df['adjusted_demand_thu']==0]['index'].values.tolist()
to_exclude_thu
# Out:
# [81,
#  107,
#  108,
#  113,
#  114,
#  117,
#  121,
#  126,
#  129,
#  131,
#  134,
#  137,
#  138,
#  140,
#  141,
#  143,
#  144,
#  147,
#  149,
#  150,
#  151,
#  153,
#  155,
#  156,
#  157,
#  159,
#  162,
#  164,
#  165,
#  166,
#  167,
#  168,
#  170,
#  171,
#  172,
#  174,
#  175,
#  176,
#  177,
#  178,
#  180,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  209,
#  210,
#  212,
#  215,
#  216,
#  218,
#  220,
#  221,
#  222,
#  224,
#  226,
#  227,
#  230,
#  231,
#  232,
#  233,
#  235,
#  237,
#  238]

# %%
dm_thu = dm_thu[~dm_thu[0].isin(to_exclude_thu)]
dm_thu = dm_thu.loc[:, ~dm_thu.loc[0].isin(to_exclude_thu)]
dm_thu = dm_thu.reset_index(drop=True)
dm_thu
# Out:
#        0        1        2        3        4        5        6        7    \
# 0      NaN   0.0000   0.0000   0.0000   1.0000   1.0000   1.0000   2.0000
# 1      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 2      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 3      0.0      inf      inf      inf   2.6786   2.6786   2.6786   2.8743
# 4      1.0   2.6786   2.6786   2.6786      inf      inf      inf   3.9804
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 188  154.0  37.0502  37.0502  37.0502  39.2061  39.2061  39.2061  37.2048
# 189  160.0  37.8368  37.8368  37.8368  39.9928  39.9928  39.9928  37.9915
# 190  161.0  38.1101  38.1101  38.1101  40.2660  40.2660  40.2660  38.2647
# 191  163.0  38.4266  38.4266  38.4266  40.5826  40.5826  40.5826  38.5813
# 192  173.0  40.1119  40.1119  40.1119  42.2679  42.2679  42.2679  40.2666
#
#          8        9    ...       196       199       202       203       205  \
# ...

# %%
thu_df1 = thu_df[~thu_df['index'].isin(to_exclude_thu)]
thu_df1.reset_index(drop=True, inplace=True)
thu_df1
# Out:
#      index           Commune   NPA Commune d'annonce / District  \
# 0        0           Penthaz  1303                      Penthaz
# 1        0           Penthaz  1303                      Penthaz
# 2        0           Penthaz  1303                      Penthaz
# 3        1         Penthalaz  1305                    Penthalaz
# 4        1         Penthalaz  1305                    Penthalaz
# ..     ...               ...   ...                          ...
# 187    154  La Tour-de-Peilz  1814             La Tour-de-Peilz
# 188    160           Clarens  1815                     Montreux
# 189    161            Blonay  1807                     Montreux
# 190    163             Gimel  1188                        Gimel
# 191    173          Prangins  1197                     Prangins
#
#      full_demand_thu  distance_to_venoge_km       P_Y  adjusted_demand_thu
# 0              100.0                   0.74  0.979204                   98
# ...

# %%
thu_df.iloc[:,:6].to_csv('demand_thu_full.csv', index=False)

# %%
thu_df1[['index','Commune','NPA',"Commune d'annonce / District",'adjusted_demand_thu','distance_to_venoge_km']].to_csv('adjusted_demand_thu.csv', index=False)

# %%
dm_thu.to_csv('adjusted_dm_thu.csv', index=False, header=False)

# %% [markdown]
# # Friday

# %%
fri_df = pd.read_csv(repo_url+'demand_fri.csv')
dm_fri = pd.read_csv(repo_url+'data/dm_vendredi.csv',header=None)

# %%
to_exclude_fri = fri_df[fri_df['adjusted_demand_fri']==0]['index'].values.tolist()
to_exclude_fri
# Out:
# [78,
#  96,
#  99,
#  100,
#  103,
#  107,
#  109,
#  110,
#  111,
#  112,
#  113,
#  116,
#  118,
#  124,
#  126,
#  129,
#  131,
#  132,
#  133,
#  134,
#  136,
#  139,
#  143,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  153,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  162,
#  163,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  172,
#  173,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  180,
#  183,
#  184,
#  185,
#  186,
#  188,
#  189,
#  190,
#  192,
#  195,
#  197,
#  198,
#  199,
#  203,
#  204,
#  205,
#  206,
#  207,
#  210,
#  211,
#  212,
#  215,
#  216,
#  217,
#  218,
#  220,
#  221,
#  223,
#  224,
#  226,
#  227,
#  228,
#  229,
#  230,
#  233]

# %%
dm_fri
# Out:
#        0        1        2        3        4        5        6        7    \
# 0      NaN   0.0000   0.0000   0.0000   1.0000   1.0000   2.0000   3.0000
# 1      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 2      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 3      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 4      1.0   2.6786   2.6786   2.6786      inf      inf   3.9804   3.0074
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 235  227.0  66.2471  66.2471  66.2471  64.3614  64.3614  66.1058  62.2520
# 236  228.0  67.3176  67.3176  67.3176  69.4735  69.4735  67.4723  69.6757
# 237  229.0  68.2641  68.2641  68.2641  66.3784  66.3784  68.1229  64.2690
# 238  230.0  68.5917  68.5917  68.5917  70.7477  70.7477  68.7464  70.9498
# 239  233.0  69.9441  69.9441  69.9441  68.0584  68.0584  69.8029  65.9490
#
#          8        9    ...       230       231       232       233       234  \
# ...

# %%
dm_fri = dm_fri[~dm_fri[0].isin(to_exclude_fri)]
dm_fri = dm_fri.loc[:, ~dm_fri.loc[0].isin(to_exclude_fri)]
dm_fri = dm_fri.reset_index(drop=True)
dm_fri
# Out:
#        0        1        2        3        4        5        6        7    \
# 0      NaN   0.0000   0.0000   0.0000   1.0000   1.0000   2.0000   3.0000
# 1      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 2      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 3      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 4      1.0   2.6786   2.6786   2.6786      inf      inf   3.9804   3.0074
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 148  135.0  33.7072  33.7072  33.7072  31.8215  31.8215  33.5660  29.7122
# 149  142.0  34.4754  34.4754  34.4754  32.5897  32.5897  34.3341  30.4803
# 150  154.0  37.0502  37.0502  37.0502  39.2061  39.2061  37.2048  39.4082
# 151  161.0  38.1101  38.1101  38.1101  40.2660  40.2660  38.2647  40.4681
# 152  171.0  39.9066  39.9066  39.9066  38.0209  38.0209  39.7653  35.9115
#
#          8        9    ...       156       157       159       161       162  \
# ...

# %%
fri_df1 = fri_df[~fri_df['index'].isin(to_exclude_fri)]
fri_df1.reset_index(drop=True, inplace=True)
fri_df1
# Out:
#      index               Commune   NPA Commune d'annonce / District  \
# 0        0               Penthaz  1303                      Penthaz
# 1        0               Penthaz  1303                      Penthaz
# 2        0               Penthaz  1303                      Penthaz
# 3        1             Penthalaz  1305                    Penthalaz
# 4        1             Penthalaz  1305                    Penthalaz
# ..     ...                   ...   ...                          ...
# 147    135               Yvonand  1462                      Yvonand
# 148    142             Champagne  1424                    Champagne
# 149    154      La Tour-de-Peilz  1814             La Tour-de-Peilz
# 150    161                Blonay  1807                     Montreux
# 151    171  La Sagne (Ste-Croix)  1450                 Sainte-Croix
#
#      full_demand_fri  distance_to_venoge_km       P_Y  adjusted_demand_fri
# 0              100.0                   0.74  0.979204                   98
# ...

# %%
fri_df.iloc[:,:6].to_csv('demand_fri_full.csv', index=False)
fri_df1[['index','Commune','NPA',"Commune d'annonce / District",'adjusted_demand_fri','distance_to_venoge_km']].to_csv('adjusted_demand_fri.csv', index=False)
dm_fri.to_csv('adjusted_dm_fri.csv', index=False, header=False)

# %% [markdown]
# # Saturday

# %%
sat_df = pd.read_csv(repo_url+'demand_sat.csv')
dm_sat = pd.read_csv(repo_url+'data/dm_samedi.csv',header=None)

# %%
to_exclude_sat = sat_df[sat_df['adjusted_demand_sat']==0]['index'].values.tolist()
to_exclude_sat
# Out:
# [88,
#  91,
#  92,
#  95,
#  100,
#  105,
#  107,
#  108,
#  112,
#  113,
#  116,
#  120,
#  124,
#  127,
#  130,
#  131,
#  133,
#  136,
#  140,
#  141,
#  142,
#  143,
#  144,
#  146,
#  148,
#  150,
#  152,
#  153,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  162,
#  164,
#  165,
#  166,
#  167,
#  171,
#  172,
#  173,
#  174,
#  175,
#  176,
#  177,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  188,
#  189,
#  191,
#  192,
#  193,
#  194,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  205,
#  206,
#  207,
#  210,
#  212,
#  215,
#  216,
#  217,
#  218,
#  220,
#  221,
#  224,
#  225,
#  226,
#  227,
#  230,
#  232,
#  233,
#  237,
#  238]

# %%
dm_sat
# Out:
#        0        1        2        3        4        5        6        7    \
# 0      NaN   0.0000   0.0000   0.0000   1.0000   1.0000   2.0000   3.0000
# 1      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 2      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 3      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 4      1.0   2.6786   2.6786   2.6786      inf      inf   3.9804   3.0074
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 244  230.0  68.5917  68.5917  68.5917  70.7477  70.7477  68.7464  70.9498
# 245  232.0  69.3386  69.3386  69.3386  71.4946  71.4946  69.4933  71.6967
# 246  233.0  69.9441  69.9441  69.9441  68.0584  68.0584  69.8029  65.9490
# 247  237.0  77.0503  77.0503  77.0503  79.2062  79.2062  77.2050  79.4084
# 248  238.0  89.0705  89.0705  89.0705  91.2265  91.2265  89.2252  91.4286
#
#          8        9    ...       239       240       241       242       243  \
# ...

# %%
dm_sat = dm_sat[~dm_sat[0].isin(to_exclude_sat)]
dm_sat = dm_sat.loc[:, ~dm_sat.loc[0].isin(to_exclude_sat)]
dm_sat = dm_sat.reset_index(drop=True)
dm_sat
# Out:
#        0        1        2        3        4        5        6        7    \
# 0      NaN   0.0000   0.0000   0.0000   1.0000   1.0000   2.0000   3.0000
# 1      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 2      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 3      0.0      inf      inf      inf   2.6786   2.6786   2.8743   4.0302
# 4      1.0   2.6786   2.6786   2.6786      inf      inf   3.9804   3.0074
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 158  135.0  33.7072  33.7072  33.7072  31.8215  31.8215  33.5660  29.7122
# 159  139.0  33.9993  33.9993  33.9993  36.1552  36.1552  34.1539  36.3573
# 160  154.0  37.0502  37.0502  37.0502  39.2061  39.2061  37.2048  39.4082
# 161  161.0  38.1101  38.1101  38.1101  40.2660  40.2660  38.2647  40.4681
# 162  163.0  38.4266  38.4266  38.4266  40.5826  40.5826  38.5813  40.7847
#
#          8        9    ...       165       167       168       170       173  \
# ...

# %%
sat_df1 = sat_df[~sat_df['index'].isin(to_exclude_sat)]
sat_df1.reset_index(drop=True, inplace=True)
sat_df1
# Out:
#      index           Commune   NPA Commune d'annonce / District  \
# 0        0           Penthaz  1303                      Penthaz
# 1        0           Penthaz  1303                      Penthaz
# 2        0           Penthaz  1303                      Penthaz
# 3        1         Penthalaz  1305                    Penthalaz
# 4        1         Penthalaz  1305                    Penthalaz
# ..     ...               ...   ...                          ...
# 157    135           Yvonand  1462                      Yvonand
# 158    139     La Conversion  1093                        Lutry
# 159    154  La Tour-de-Peilz  1814             La Tour-de-Peilz
# 160    161            Blonay  1807                     Montreux
# 161    163             Gimel  1188                        Gimel
#
#      full_demand_sat  distance_to_venoge_km       P_Y  adjusted_demand_sat
# 0              100.0                   0.74  0.979204                   98
# ...

# %%
sat_df.iloc[:,:6].to_csv('demand_sat_full.csv', index=False)
sat_df1[['index','Commune','NPA',"Commune d'annonce / District",'adjusted_demand_sat','distance_to_venoge_km']].to_csv('adjusted_demand_sat.csv', index=False)
dm_sat.to_csv('adjusted_dm_sat.csv', index=False, header=False)
